# %% [markdown]
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %% [markdown]
# ● Get all the Earth meteorites that fell before the year 2000

# %%
import pandas as pd
import matplotlib.pyplot as plt

def create_graph(csv_file):
    # Reading CSV data into a pandas DataFrame
    df = pd.read_csv(csv_file)

    # Group the data by 'year' and count the occurrences
    year_counts = df['year'].value_counts().sort_index()

    # Plotting the bar graph
    plt.bar(year_counts.index, year_counts.values)
    plt.xlabel('Year')
    plt.ylabel('Count')
    plt.title('Meteorite Falls by Year')

    # Showing the graph
    plt.show()

csv_file_path = '/content/nasa.csv'

create_graph(csv_file_path)

# %% [markdown]
# ● Get all the earth meteorites co-ordinates who fell before the year 1970

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def get_coordinates(csv_file):

  ### Reading csv data into a pandas DataFrame

  df = pd.read_csv(csv_file)

  filtering_df = df[(df['year'] < '1970-01-01') & (df['fall'] == 'Fell')]
  ## Extracting the coordinates
  coordinates = filtering_df[['reclat','reclong']]
  
  ## Removing rows with missing Coordinates
  coordinates = coordinates.dropna()
  coordinates_list = list(coordinates.itertuples(index=False, name=None))
  return coordinates_list


csv_file_path = '/content/nasa.csv'

coordinates = get_coordinates(csv_file_path)
print(coordinates)
# Out:
# [(50.775, 6.08333), (56.18333, 10.23333), (54.21667, -113.0), (-33.16667, -64.95), (32.1, 71.8), (44.83333, 95.16667), (44.21667, 0.61667), (-31.6, -65.23333), (-30.86667, -64.55), (19.08333, 8.38333), (50.66667, 2.33333), (29.51667, 35.05), (29.71667, 77.95), (8.91667, 8.43333), (24.41667, 39.51667), (44.11667, 4.08333), (44.65, 11.01667), (2.0, 22.66667), (51.78333, -1.78333), (36.23333, 37.13333), (44.88333, 8.75), (50.95, 31.81667), (45.26667, 10.15), (42.53333, -85.88333), (26.96667, -105.31667), (27.66667, 78.25), (26.58333, 85.56667), (44.61667, -70.75), (48.7, 37.5), (20.88333, 76.86667), (47.46667, -0.55), (-22.96667, -44.31667), (9.53333, 39.71667), (53.58333, -2.71667), (43.86667, 5.38333), (-33.0, -66.0), (38.5, -94.3), (-31.41667, -60.66667), (42.45, 9.03333), (52.05, 0.3), (43.03333, 12.55), (25.25417, 80.625), (20.06667, -103.66667), (34.75, -87.0), (34.31667, -96.15), (44.38333, 5.16667), (36.16667, 3.66667), (44.33333, 3.23333), (43.08333, 0.58333), (-21.46028, -49.9
# ...

# %% [markdown]
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

# %%
filtered_df = df[df['mass'] > 10000]

# Extract the relevant columns
result = filtered_df[['name', 'id', 'mass', 'fall', 'year']]

result
# Out:
#            name     id      mass  fall                     year
# 2          Abee      6  107000.0  Fell  1952-01-01T00:00:00.000
# 7          Agen    392   30000.0  Fell  1814-01-01T00:00:00.000
# 11          Aïr    424   24000.0  Fell  1925-01-01T00:00:00.000
# 16      Akyumak    433   50000.0  Fell  1981-01-01T00:00:00.000
# 27   Alfianello    466  228000.0  Fell  1883-01-01T00:00:00.000
# ..          ...    ...       ...   ...                      ...
# 991   Tieschitz  23989   28000.0  Fell  1878-01-01T00:00:00.000
# 992      Tilden  23998   74800.0  Fell  1927-01-01T00:00:00.000
# 994    Timochin  24004   65500.0  Fell  1807-01-01T00:00:00.000
# 997       Tjabe  24011   20000.0  Fell  1869-01-01T00:00:00.000
# 998    Tjerebon  24012   16500.0  Fell  1922-01-01T00:00:00.000
#
# [243 rows x 5 columns]

# %%
import pandas as pd

def getting_mass_meteorites(csv_file):
  df = pd.read_csv(csv_file)
  filtering_df = df[df['mass']>1000]
  result = filtering_df[['name','id','mass','fall','year']]
  return result
## Driver Code
csv_file_path = '/content/nasa.csv'
res = getting_mass_meteorites(csv_file_path)
print(res)
# Out:
#           name     id      mass  fall                     year
# 2         Abee      6  107000.0  Fell  1952-01-01T00:00:00.000
# 3     Acapulco     10    1914.0  Fell  1976-01-01T00:00:00.000
# 5     Adhi Kot    379    4239.0  Fell  1919-01-01T00:00:00.000
# 7         Agen    392   30000.0  Fell  1814-01-01T00:00:00.000
# 8       Aguada    398    1620.0  Fell  1930-01-01T00:00:00.000
# ..         ...    ...       ...   ...                      ...
# 993  Tillaberi  23999    3000.0  Fell  1970-01-01T00:00:00.000
# 994   Timochin  24004   65500.0  Fell  1807-01-01T00:00:00.000
# 996    Tissint  54823    7000.0  Fell  2011-01-01T00:00:00.000
# 997      Tjabe  24011   20000.0  Fell  1869-01-01T00:00:00.000
# 998   Tjerebon  24012   16500.0  Fell  1922-01-01T00:00:00.000
#
# [654 rows x 5 columns]

# %% [markdown]
# ● Get the summary for the most popular ( ratings ) episode in every season

# %%
import requests

# Fetch data from the API
response = requests.get('http://api.tvmaze.com/singlesearch/shows?q=westworld&embed=episodes')
data = response.json()

# Extract the episode information
episodes = data['_embedded']['episodes']

# Initialize a dictionary to store the most popular episodes for each season
most_popular_episodes = {}

# Iterate over the episodes to find the most popular episode in each season
for episode in episodes:
    season_number = episode['season']
    episode_name = episode['name']
    episode_rating = episode['rating']['average']
    episode_summary = episode['summary']

    if season_number not in most_popular_episodes:
        most_popular_episodes[season_number] = {'episode': episode_name, 'rating': episode_rating, 'summary': episode_summary}
    else:
        if episode_rating > most_popular_episodes[season_number]['rating']:
            most_popular_episodes[season_number] = {'episode': episode_name, 'rating': episode_rating, 'summary': episode_summary}

# Print the summary for the most popular episode in each season
for season_number in most_popular_episodes:
    print(f"Season {season_number}:")
    print("Most Popular Episode - Episode:", most_popular_episodes[season_number]['episode'])
    print("Rating:", most_popular_episodes[season_number]['rating'])
    print("Summary:", most_popular_episodes[season_number]['summary'])
    print()
# Out:
# Season 1:
# Most Popular Episode - Episode: The Bicameral Mind
# Rating: 8.7
# Summary: <p>Delores finds out the truth about William's fate. Meanwhile, Maeve organizes an escape plan, only to discover that someone else is pulling the strings. And Robert plays the final piece in his grand narrative.</p>
#
# Season 2:
# Most Popular Episode - Episode: Kiksuya
# Rating: 8.7
# Summary: <p>Another of Westworld's Host revolutionaries is revealed. Meanwhile, Emily finds the Man and convinces the Ghost Nation to hand him over to her to ensure his suffering.</p>
#
# Season 3:
# Most Popular Episode - Episode: Parce Domine
# Rating: 8
# Summary: <p>If you're stuck in a loop, try walking in a straight line.</p>
#
# Season 4:
# Most Popular Episode - Episode: Zhuangzi
# Rating: 7.8
# Summary: <p>God is bored.</p>

# %% [markdown]
# Write a program to read the data from the following link, perform data analysis and answer the following questions

# %% [markdown]
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
import pandas as pd

# Read the data from the provided link
url = 'https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD'

df = pd.read_csv(url)
df.columns
# Out:
# Index(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code', 'Model Year',
#        'Make', 'Model', 'Electric Vehicle Type',
#        'Clean Alternative Fuel Vehicle (CAFV) Eligibility', 'Electric Range',
#        'Base MSRP', 'Legislative District', 'DOL Vehicle ID',
#        'Vehicle Location', 'Electric Utility', '2020 Census Tract'],
#       dtype='object')

# %%
df.head()
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
df['Electric Vehicle Type'].unique()
# Out:
# array(['Battery Electric Vehicle (BEV)',
#        'Plug-in Hybrid Electric Vehicle (PHEV)'], dtype=object)

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts()
# Out:
# Clean Alternative Fuel Vehicle Eligible                         60551
# Eligibility unknown as battery range has not been researched    53446
# Not eligible due to low battery range                           16446
# Name: Clean Alternative Fuel Vehicle (CAFV) Eligibility, dtype: int64

# %%
x = df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == 'Not eligible due to low battery range']

# %%
df1 = x.drop(['VIN (1-10)', 'County', 'City', 'State', 'Postal Code','Legislative District', 'DOL Vehicle ID',
       'Vehicle Location', 'Electric Utility', '2020 Census Tract'],axis = 1)

# %%
df1
# Out:
#         Model Year    Make        Model  \
# 6             2016    FORD       FUSION
# 7             2023    AUDI         Q5 E
# 8             2014    FORD        C-MAX
# 14            2017    FORD        C-MAX
# 15            2020     KIA         NIRO
# ...            ...     ...          ...
# 130377        2019     BMW         530E
# 130385        2016    AUDI           A3
# 130390        2023    JEEP     WRANGLER
# 130407        2017  TOYOTA  PRIUS PRIME
# 130437        2021     BMW         530E
#
#                          Electric Vehicle Type  \
# 6       Plug-in Hybrid Electric Vehicle (PHEV)
# 7       Plug-in Hybrid Electric Vehicle (PHEV)
# 8       Plug-in Hybrid Electric Vehicle (PHEV)
# 14      Plug-in Hybrid Electric Vehicle (PHEV)
# 15      Plug-in Hybrid Electric Vehicle (PHEV)
# ...                                        ...
# 130377  Plug-in Hybrid Electric Vehicle (PHEV)
# 130385  Plug-in Hybrid Electric Vehicle (PHEV)
# ...

# %% [markdown]
# ● Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
tesla_cars = df[(df['Make'] == 'TESLA') & (df['City'] == 'BOTHELL')]
model_years = tesla_cars['Model Year'].tolist()
model_types = tesla_cars['Model'].tolist()

# %%
tesla_cars = df[(df['Make'] == 'TESLA') & (df['City'] == 'BOTHELL')]

# Get the model year and model type of the TESLA cars
model_years = tesla_cars['Model Year'].tolist()
model_types = tesla_cars['Model'].tolist()
df3 = pd.DataFrame(model_years,model_types)
df3

# %%
df4 = pd.DataFrame(tesla_cars)
df4
# Out:
# Empty DataFrame
# Columns: [VIN (1-10), County, City, State, Postal Code, Model Year, Make, Model, Electric Vehicle Type, Clean Alternative Fuel Vehicle (CAFV) Eligibility, Electric Range, Base MSRP, Legislative District, DOL Vehicle ID, Vehicle Location, Electric Utility, 2020 Census Tract]
# Index: []

# %% [markdown]
# Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df5 = df[(df['Electric Range'] >= 100 ) & (df['Model Year'] >= 2015)]
df5
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130418  5YJSA1E22F      King         Vashon    WA      98070.0        2015
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %%
df6  = df[(df['Electric Range'] >= 100) & (df['Model Year'] >= 2015)]
df6
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130418  5YJSA1E22F      King         Vashon    WA      98070.0        2015
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
grouped_data = df.groupby(['City', 'Electric Vehicle Type']).size().reset_index(name='Count')
# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(grouped_data['Electric Vehicle Type'], bins=10, edgecolor='black', alpha=0.7)
plt.xlabel('Electric Vehicle Type')
plt.ylabel('Frequency')
plt.title('Distribution of Electric Vehicle Types')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Question 10 -
#
# Write a program to count the number of verbs, nouns, pronouns, and adjectives in a given particular phrase or paragraph, and return their respective count as a dictionary.
